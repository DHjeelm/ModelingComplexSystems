# %%
# Import and create graph of the football network provided by NetworkX
import urllib.request
import io
import zipfile
import numpy as np
import random

import matplotlib.pyplot as plt
import networkx as nx

url = "http://www-personal.umich.edu/~mejn/netdata/football.zip"

sock = urllib.request.urlopen(url)  # open URL
s = io.BytesIO(sock.read())  # read into BytesIO "file"
sock.close()

zf = zipfile.ZipFile(s)  # zipfile object
txt = zf.read("football.txt").decode()  # read info file
gml = zf.read("football.gml").decode()  # read gml data
# throw away bogus first line with # from mejn files
gml = gml.split("\n")[1:]
G = nx.parse_gml(gml)  # parse gml data

print(txt)
# print degree for each team - number of games
for n, d in G.degree():
    print(f"{n:20} {d:2}")

options = {"node_color": "black", "node_size": 50, "linewidths": 0, "width": 0.1}

pos = nx.spring_layout(G, seed=1969)  # Seed for reproducible layout
nx.draw(G, pos, **options)
plt.show()
# Out:
# The file football.gml contains the network of American football games
# between Division IA colleges during regular season Fall 2000, as compiled
# by M. Girvan and M. Newman.  The nodes have values that indicate to which
# conferences they belong.  The values are as follows:
#
#   0 = Atlantic Coast
#   1 = Big East
#   2 = Big Ten
#   3 = Big Twelve
#   4 = Conference USA
#   5 = Independents
#   6 = Mid-American
#   7 = Mountain West
#   8 = Pacific Ten
#   9 = Southeastern
#  10 = Sun Belt
#  11 = Western Athletic
#
# If you make use of these data, please cite M. Girvan and M. E. J. Newman,
# Community structure in social and biological networks,
# Proc. Natl. Acad. Sci. USA 99, 7821-7826 (2002).
#
# Correction: Two edges were erroneously duplicated in this data set, and
# have been removed (21 SEP 2014)
#
# BrighamYoung         12
# FloridaState         12
# Iowa                 12
# KansasState          12
# NewMexico            11
# TexasTech            12
# PennState            12
# SouthernCalifornia   12
# ArizonaState         11
# SanDiegoState        11
# Baylor               10
# NorthTexas           10
# NorthernIllinois     10
# Northwestern         11
# WesternMichigan      10
# Wisconsin            12
# Wyoming              11
# Auburn               11
# Akron                11
# VirginiaTech         11
# Alabama              11
# UCLA                 11
# Arizona              11
# Utah                 11
# ArkansasState        10
# NorthCarolinaState   11
# BallState            10
# Florida              11
# BoiseState            9
# BostonCollege        11
# WestVirginia         11
# BowlingGreenState    11
# Michigan             11
# Virginia             10
# Buffalo              11
# Syracuse             11
# CentralFlorida        8
# GeorgiaTech          11
# CentralMichigan      11
# Purdue               11
# Colorado             11
# ColoradoState        10
# Connecticut           7
# EasternMichigan      11
# EastCarolina         11
# Duke                 11
# FresnoState          11
# OhioState            11
# Houston              11
# Rice                 11
# Idaho                 9
# Washington           11
# Kansas               10
# SouthernMethodist    12
# Kent                 10
# Pittsburgh           11
# Kentucky             10
# Louisville           10
# LouisianaTech        10
# LouisianaMonroe       8
# Minnesota            11
# MiamiOhio            11
# Vanderbilt           11
# MiddleTennesseeState  9
# Illinois             11
# MississippiState     11
# Memphis              11
# Nevada               12
# Oregon               11
# NewMexicoState       11
# SouthCarolina        11
# Ohio                 10
# IowaState            11
# SanJoseState         11
# Nebraska             11
# SouthernMississippi  10
# Tennessee            11
# Stanford             11
# WashingtonState      11
# Temple               11
# Navy                 11
# TexasA&M             11
# NotreDame            11
# TexasElPaso          11
# Oklahoma             11
# Toledo                9
# Tulane               11
# Mississippi          11
# Tulsa                12
# NorthCarolina        11
# UtahState             9
# Army                 11
# Cincinnati           11
# AirForce             10
# Rutgers              10
# Georgia              10
# LouisianaState       10
# LouisianaLafayette    8
# Texas                11
# Marshall             10
# MichiganState        11
# MiamiFlorida         10
# Missouri             10
# Clemson              10
# NevadaLasVegas       12
# WakeForest           10
# Indiana              11
# OklahomaState        10
# OregonState          10
# Maryland             11
# TexasChristian       11
# California           11
# AlabamaBirmingham    10
# Arkansas             10
# Hawaii               11

# %%
# Get the degree sequence of the network
degreeSequence = []
for n, d in G.degree():
    degreeSequence.append(d)

# Create configuration model from the degree sequence
configurationModel = nx.configuration_model(degreeSequence)

# Go from MultiGraph to Graph (Remove parallel edges)
configurationModel = nx.Graph(configurationModel)

# %%
# 1. Edges deleted are chosen randomly
numberOfSimulation = 10
numberOfStepsAlpha = 100
alphas = np.linspace(0, 1, numberOfStepsAlpha)
clusterCoefficientMatrix = np.zeros((numberOfSimulation, numberOfStepsAlpha))




# Loop over of simulations
for i in range(numberOfSimulation):
    
    # Loop over alphas
    for j in range(numberOfStepsAlpha):

        # Initialize network
        network = G.copy()
        # network = configurationModel.copy()
        
        # Fetch alpha
        alpha = alphas[j]

        # Find the amount of edges to delete
        numberOfEdges = network.number_of_edges()
        numberOfDeletedEdges = round(numberOfEdges * alpha)
        # print(f"Number of edges before: {numberOfEdges}")

        # Delete random nodes
        for k in range(numberOfDeletedEdges):
       
            # Select random edge to be deleted
            randomSample = random.sample(network.edges(), 1)

            # Delete random node
            network.remove_edges_from(randomSample)
        
        # print(f"Number of edges after deletion: {network.number_of_edges()}")


        # Calculate global clustering coefficient for the alpha      
        clusterCoefficientMatrix[i,j] = nx.transitivity(network)

# %%
# Take average over the simulations
clusterCoefficientList =[]
for i in range(numberOfStepsAlpha):
    clusterCoefficientList.append(np.mean(clusterCoefficientMatrix[:,i]))

# %%
# Plotting
plt.figure(1)
plt.title("Global clustering coefficient as function of alpha")
plt.plot(alphas, clusterCoefficientList)
plt.ylabel("Global clustering coefficient")
plt.xlabel("Alpha")
plt.show()

# %% [markdown]
# ## 2

# %%
numberOfNodes = G.number_of_nodes()
numberOfEdges = configurationModel.number_of_edges()

clusterCoefficientMatrix2 = np.zeros((numberOfSimulation, numberOfStepsAlpha))


for i in range(numberOfSimulation):
    for j, alpha in enumerate(alphas):

        network = configurationModel.copy()

        degrees = network.degree()
        edgesToRemove = round(alpha * numberOfEdges)

        for edge in range(edgesToRemove):
            node = sorted(degrees, key=lambda x: x[1], reverse=True)[0]
            edges = network.edges(node)
            
            # print(random.sample(list(edges), 1))
     
            network.remove_edges_from(random.sample(list(edges), 1))
            

        clusterCoefficientMatrix2[i,j] = nx.transitivity(network)

# %%
# Take average over the simulations
clusterCoefficientList2 =[]
for i in range(numberOfStepsAlpha):
    clusterCoefficientList2.append(np.mean(clusterCoefficientMatrix2[:,i]))

# Plotting
plt.figure(2)
plt.title("Global clustering coefficient as function of alpha")
plt.plot(alphas, clusterCoefficientList2)
plt.ylabel("Global clustering coefficient")
plt.xlabel("Alpha")
plt.show()

# %% [markdown]
# ## 3

# %%
# Start with random node. Remove alpha * nNeighbors edges, choose the neighbor with the highest degree and 
# repeat the process of deleting edges and choosing next node

from networkx import all_neighbors

numberOfSimulation = 10

G = nx.parse_gml(gml)  # parse gml data
numberOfNodes = G.number_of_nodes()
clusterCoefficientMatrix3 = np.zeros((numberOfSimulation, numberOfStepsAlpha))


for i in range(numberOfSimulation):
    for j, alpha in enumerate(alphas):

        network = G.copy()
        numberOfEdges = network.number_of_edges()
        nrEdgesToRemove = round(alpha*numberOfEdges)
        currentNode = random.sample(network.nodes(), 1)[0]

        while True:
            edges = network.edges(currentNode)
            if (len(edges) == 0):
                currentNode = random.sample(network.nodes(), 1)[0]
                continue
            edgesToRemove = random.sample(list(edges), 1)
            network.remove_edges_from(edgesToRemove)
            nrEdgesToRemove -= 1
            maxDegree = 0
            neighbors = list(all_neighbors(network, currentNode))
            if len(neighbors) == 0:
                currentNode = random.sample(network.nodes(), 1)[0]
                continue
            nextNode = None
            for k, n in enumerate(neighbors):
                if network.degree(n) > maxDegree:
                    maxDegree = network.degree(n)
                    nextNode = n

            currentNode = nextNode

            if edgesToRemove == 0:
                break
            print(f"Edges left to remove: {nrEdgesToRemove}")


        clusterCoefficientMatrix3[i,j] = nx.transitivity(network)



# Take average over the simulations
clusterCoefficientList3 =[]
for i in range(numberOfStepsAlpha):
    clusterCoefficientList3.append(np.mean(clusterCoefficientMatrix3[:,i]))

# Plotting
plt.figure(2)
plt.title("Global clustering coefficient as function of alpha")
plt.plot(alphas, clusterCoefficientList3)
plt.ylabel("Global clustering coefficient")
plt.xlabel("Alpha")
plt.show()
# Out:
# Edges left to remove: -1
# Edges left to remove: -2
# Edges left to remove: -3
# Edges left to remove: -4
# Edges left to remove: -5
# Edges left to remove: -6
# Edges left to remove: -7
# Edges left to remove: -8
# Edges left to remove: -9
# Edges left to remove: -10
# Edges left to remove: -11
# Edges left to remove: -12
# Edges left to remove: -13
# Edges left to remove: -14
# Edges left to remove: -15
# Edges left to remove: -16
# Edges left to remove: -17
# Edges left to remove: -18
# Edges left to remove: -19
# Edges left to remove: -20
# Edges left to remove: -21
# Edges left to remove: -22
# Edges left to remove: -23
# Edges left to remove: -24
# Edges left to remove: -25
# Edges left to remove: -26
# Edges left to remove: -27
# Edges left to remove: -28
# Edges left to remove: -29
# Edges left to remove: -30
# Edges left to remove: -31
# Edges left to remove: -32
# Edges left to remove: -33
# Edges left to remove: -34
# Edges left to remove: -35
# Edges left to remove: -36
# Edges left to remove: -37
# Edges left to remove: -38
# Edges left to remove: -39
# Edges left to remove: -40
# Edges left to remove: -41
# Edges left to remove: -42
# Edges left to remove: -43
# Edges left to remove: -44
# Edges left to remove: -45
# Edges left to remove: -46
# Edges left to remove: -47
# Edges left to remove: -48
# Edges left to remove: -49
# Edges left to remove: -50
# Edges left to remove: -51
# Edges left to remove: -52
# Edges left to remove: -53
# Edges left to remove: -54
# Edges left to remove: -55
# Edges left to remove: -56
# Edges left to remove: -57
# Edges left to remove: -58
# Edges left to remove: -59
# Edges left to remove: -60
# Edges left to remove: -61
# Edges left to remove: -62
# Edges left to remove: -63
# Edges left to remove: -64
# Edges left to remove: -65
# Edges left to remove: -66
# Edges left to remove: -67
# Edges left to remove: -68
# Edges left to remove: -69
# Edges left to remove: -70
# Edges left to remove: -71
# Edges left to remove: -72
# Edges left to remove: -73
# Edges left to remove: -74
# Edges left to remove: -75
# Edges left to remove: -76
# Edges left to remove: -77
# Edges left to remove: -78
# Edges left to remove: -79
# Edges left to remove: -80
# Edges left to remove: -81
# Edges left to remove: -82
# Edges left to remove: -83
# Edges left to remove: -84
# Edges left to remove: -85
# Edges left to remove: -86
# Edges left to remove: -87
# Edges left to remove: -88
# Edges left to remove: -89
# Edges left to remove: -90
# Edges left to remove: -91
# Edges left to remove: -92
# Edges left to remove: -93
# Edges left to remove: -94
# Edges left to remove: -95
# Edges left to remove: -96
# Edges left to remove: -97
# Edges left to remove: -98
# Edges left to remove: -99
# Edges left to remove: -100
# Edges left to remove: -101
# Edges left to remove: -102
# Edges left to remove: -103
# Edges left to remove: -104
# Edges left to remove: -105
# Edges left to remove: -106
# Edges left to remove: -107
# Edges left to remove: -108
# Edges left to remove: -109
# Edges left to remove: -110
# Edges left to remove: -111
# Edges left to remove: -112
# Edges left to remove: -113
# Edges left to remove: -114
# Edges left to remove: -115
# Edges left to remove: -116
# Edges left to remove: -117
# Edges left to remove: -118
# Edges left to remove: -119
# Edges left to remove: -120
# Edges left to remove: -121
# Edges left to remove: -122
# Edges left to remove: -123
# Edges left to remove: -124
# Edges left to remove: -125
# Edges left to remove: -126
# Edges left to remove: -127
# Edges left to remove: -128
# Edges left to remove: -129
# Edges left to remove: -130
# Edges left to remove: -131
# Edges left to remove: -132
# Edges left to remove: -133
# Edges left to remove: -134
# Edges left to remove: -135
# Edges left to remove: -136
# Edges left to remove: -137
# Edges left to remove: -138
# Edges left to remove: -139
# Edges left to remove: -140
# Edges left to remove: -141
# Edges left to remove: -142
# Edges left to remove: -143
# Edges left to remove: -144
# Edges left to remove: -145
# Edges left to remove: -146
# Edges left to remove: -147
# Edges left to remove: -148
# Edges left to remove: -149
# Edges left to remove: -150
# Edges left to remove: -151
# Edges left to remove: -152
# Edges left to remove: -153
# Edges left to remove: -154
# Edges left to remove: -155
# Edges left to remove: -156
# Edges left to remove: -157
# Edges left to remove: -158
# Edges left to remove: -159
# Edges left to remove: -160
# Edges left to remove: -161
# Edges left to remove: -162
# Edges left to remove: -163
# Edges left to remove: -164
# Edges left to remove: -165
# Edges left to remove: -166
# Edges left to remove: -167
# Edges left to remove: -168
# Edges left to remove: -169
# Edges left to remove: -170
# Edges left to remove: -171
# Edges left to remove: -172
# Edges left to remove: -173
# Edges left to remove: -174
# Edges left to remove: -175
# Edges left to remove: -176
# Edges left to remove: -177
# Edges left to remove: -178
# Edges left to remove: -179
# Edges left to remove: -180
# Edges left to remove: -181
# Edges left to remove: -182
# Edges left to remove: -183
# Edges left to remove: -184
# Edges left to remove: -185
# Edges left to remove: -186
# Edges left to remove: -187
# Edges left to remove: -188
# Edges left to remove: -189
# Edges left to remove: -190
# Edges left to remove: -191
# Edges left to remove: -192
# Edges left to remove: -193
# Edges left to remove: -194
# Edges left to remove: -195
# Edges left to remove: -196
# Edges left to remove: -197
# Edges left to remove: -198
# Edges left to remove: -199
# Edges left to remove: -200
# Edges left to remove: -201
# Edges left to remove: -202
# Edges left to remove: -203
# Edges left to remove: -204
# Edges left to remove: -205
# Edges left to remove: -206
# Edges left to remove: -207
# Edges left to remove: -208
# Edges left to remove: -209
# Edges left to remove: -210
# Edges left to remove: -211
# Edges left to remove: -212
# Edges left to remove: -213
# Edges left to remove: -214
# Edges left to remove: -215
# Edges left to remove: -216
# Edges left to remove: -217
# Edges left to remove: -218
# Edges left to remove: -219
# Edges left to remove: -220
# Edges left to remove: -221
# Edges left to remove: -222
# Edges left to remove: -223
# Edges left to remove: -224
# Edges left to remove: -225
# Edges left to remove: -226
# Edges left to remove: -227
# Edges left to remove: -228
# Edges left to remove: -229
# Edges left to remove: -230
# Edges left to remove: -231
# Edges left to remove: -232
# Edges left to remove: -233
# Edges left to remove: -234
# Edges left to remove: -235
# Edges left to remove: -236
# Edges left to remove: -237
# Edges left to remove: -238
# Edges left to remove: -239
# Edges left to remove: -240
# Edges left to remove: -241
# Edges left to remove: -242
# Edges left to remove: -243
# Edges left to remove: -244
# Edges left to remove: -245
# Edges left to remove: -246
# Edges left to remove: -247
# Edges left to remove: -248
# Edges left to remove: -249
# Edges left to remove: -250
# Edges left to remove: -251
# Edges left to remove: -252
# Edges left to remove: -253
# Edges left to remove: -254
# Edges left to remove: -255
# Edges left to remove: -256
# Edges left to remove: -257
# Edges left to remove: -258
# Edges left to remove: -259
# Edges left to remove: -260
# Edges left to remove: -261
# Edges left to remove: -262
# Edges left to remove: -263
# Edges left to remove: -264
# Edges left to remove: -265
# Edges left to remove: -266
# Edges left to remove: -267
# Edges left to remove: -268
# Edges left to remove: -269
# Edges left to remove: -270
# Edges left to remove: -271
# Edges left to remove: -272
# Edges left to remove: -273
# Edges left to remove: -274
# Edges left to remove: -275
# Edges left to remove: -276
# Edges left to remove: -277
# Edges left to remove: -278
# Edges left to remove: -279
# Edges left to remove: -280
# Edges left to remove: -281
# Edges left to remove: -282
# Edges left to remove: -283
# Edges left to remove: -284
# Edges left to remove: -285
# Edges left to remove: -286
# Edges left to remove: -287
# Edges left to remove: -288
# Edges left to remove: -289
# Edges left to remove: -290
# Edges left to remove: -291
# Edges left to remove: -292
# Edges left to remove: -293
# Edges left to remove: -294
# Edges left to remove: -295
# Edges left to remove: -296
# Edges left to remove: -297
# Edges left to remove: -298
# Edges left to remove: -299
# Edges left to remove: -300
# Edges left to remove: -301
# Edges left to remove: -302
# Edges left to remove: -303
# Edges left to remove: -304
# Edges left to remove: -305
# Edges left to remove: -306
# Edges left to remove: -307
# Edges left to remove: -308
# Edges left to remove: -309
# Edges left to remove: -310
# Edges left to remove: -311
# Edges left to remove: -312
# Edges left to remove: -313
# Edges left to remove: -314
# Edges left to remove: -315
# Edges left to remove: -316
# Edges left to remove: -317
# Edges left to remove: -318
# Edges left to remove: -319
# Edges left to remove: -320
# Edges left to remove: -321
# Edges left to remove: -322
# Edges left to remove: -323
# Edges left to remove: -324
# Edges left to remove: -325
# Edges left to remove: -326
# Edges left to remove: -327
# Edges left to remove: -328
# Edges left to remove: -329
# Edges left to remove: -330
# Edges left to remove: -331
# Edges left to remove: -332
# Edges left to remove: -333
# Edges left to remove: -334
# Edges left to remove: -335
# Edges left to remove: -336
# Edges left to remove: -337
# Edges left to remove: -338
# Edges left to remove: -339
# Edges left to remove: -340
# Edges left to remove: -341
# Edges left to remove: -342
# Edges left to remove: -343
# Edges left to remove: -344
# Edges left to remove: -345
# Edges left to remove: -346
# Edges left to remove: -347
# Edges left to remove: -348
# Edges left to remove: -349
# Edges left to remove: -350
# Edges left to remove: -351
# Edges left to remove: -352
# Edges left to remove: -353
# Edges left to remove: -354
# Edges left to remove: -355
# Edges left to remove: -356
# Edges left to remove: -357
# Edges left to remove: -358
# Edges left to remove: -359
# Edges left to remove: -360
# Edges left to remove: -361
# Edges left to remove: -362
# Edges left to remove: -363
# Edges left to remove: -364
# Edges left to remove: -365
# Edges left to remove: -366
# Edges left to remove: -367
# Edges left to remove: -368
# Edges left to remove: -369
# Edges left to remove: -370
# Edges left to remove: -371
# Edges left to remove: -372
# Edges left to remove: -373
# Edges left to remove: -374
# Edges left to remove: -375
# Edges left to remove: -376
# Edges left to remove: -377
# Edges left to remove: -378
# Edges left to remove: -379
# Edges left to remove: -380
# Edges left to remove: -381
# Edges left to remove: -382
# Edges left to remove: -383
# Edges left to remove: -384
# Edges left to remove: -385
# Edges left to remove: -386
# Edges left to remove: -387
# Edges left to remove: -388
# Edges left to remove: -389
# Edges left to remove: -390
# Edges left to remove: -391
# Edges left to remove: -392
# Edges left to remove: -393
# Edges left to remove: -394
# Edges left to remove: -395
# Edges left to remove: -396
# Edges left to remove: -397
# Edges left to remove: -398
# Edges left to remove: -399
# Edges left to remove: -400
# Edges left to remove: -401
# Edges left to remove: -402
# Edges left to remove: -403
# Edges left to remove: -404
# Edges left to remove: -405
# Edges left to remove: -406
# Edges left to remove: -407
# Edges left to remove: -408
# Edges left to remove: -409
# Edges left to remove: -410
# Edges left to remove: -411
# Edges left to remove: -412
# Edges left to remove: -413
# Edges left to remove: -414
# Edges left to remove: -415
# Edges left to remove: -416
# Edges left to remove: -417
# Edges left to remove: -418
# Edges left to remove: -419
# Edges left to remove: -420
# Edges left to remove: -421
# Edges left to remove: -422
# Edges left to remove: -423
# Edges left to remove: -424
# Edges left to remove: -425
# Edges left to remove: -426
# Edges left to remove: -427
# Edges left to remove: -428
# Edges left to remove: -429
# Edges left to remove: -430
# Edges left to remove: -431
# Edges left to remove: -432
# Edges left to remove: -433
# Edges left to remove: -434
# Edges left to remove: -435
# Edges left to remove: -436
# Edges left to remove: -437
# Edges left to remove: -438
# Edges left to remove: -439
# Edges left to remove: -440
# Edges left to remove: -441
# Edges left to remove: -442
# Edges left to remove: -443
# Edges left to remove: -444
# Edges left to remove: -445
# Edges left to remove: -446
# Edges left to remove: -447
# Edges left to remove: -448
# Edges left to remove: -449
# Edges left to remove: -450
# Edges left to remove: -451
# Edges left to remove: -453
# Edges left to remove: -454
# Edges left to remove: -455
# Edges left to remove: -456
# Edges left to remove: -457
# Edges left to remove: -458
# Edges left to remove: -459
# Edges left to remove: -460
# Edges left to remove: -461
# Edges left to remove: -462
# Edges left to remove: -463
# Edges left to remove: -464
# Edges left to remove: -465
# Edges left to remove: -466
# Edges left to remove: -467
# Edges left to remove: -470
# Edges left to remove: -471
# Edges left to remove: -472
# Edges left to remove: -473
# Edges left to remove: -474
# Edges left to remove: -475
# Edges left to remove: -476
# Edges left to remove: -477
# Edges left to remove: -478
# Edges left to remove: -479
# Edges left to remove: -482
# Edges left to remove: -483
# Edges left to remove: -484
# Edges left to remove: -485
# Edges left to remove: -487
# Edges left to remove: -488
# Edges left to remove: -489
# Edges left to remove: -490
# Edges left to remove: -491
# Edges left to remove: -492
# Edges left to remove: -493
# Edges left to remove: -494
# Edges left to remove: -495
# Edges left to remove: -496
# Edges left to remove: -497
# Edges left to remove: -498
# Edges left to remove: -499
# Edges left to remove: -500
# Edges left to remove: -501
# Edges left to remove: -502
# Edges left to remove: -503
# Edges left to remove: -504
# Edges left to remove: -505
# Edges left to remove: -506
# Edges left to remove: -508
# Edges left to remove: -509
# Edges left to remove: -510
# Edges left to remove: -511
# Edges left to remove: -512
# Edges left to remove: -513
# Edges left to remove: -514
# Edges left to remove: -515
# Edges left to remove: -516
# Edges left to remove: -518
# Edges left to remove: -519
# Edges left to remove: -520
# Edges left to remove: -521
# Edges left to remove: -523
# Edges left to remove: -524
# Edges left to remove: -529
# Edges left to remove: -530
# Edges left to remove: -531
# Edges left to remove: -534
# Edges left to remove: -535
# Edges left to remove: -538
# Edges left to remove: -540
# Edges left to remove: -548
# Edges left to remove: -549
# Edges left to remove: -552
# Edges left to remove: -553
# Edges left to remove: -554
# Edges left to remove: -557
# Edges left to remove: -558
# Edges left to remove: -559
# Edges left to remove: -560
# Edges left to remove: -562
# Edges left to remove: -563
# Edges left to remove: -564
# Edges left to remove: -565
# Edges left to remove: -566
# Edges left to remove: -567
# Edges left to remove: -568
# Edges left to remove: -569
# Edges left to remove: -570
# Edges left to remove: -573
# Edges left to remove: -574
# Edges left to remove: -575
# Edges left to remove: -576
# Edges left to remove: -577
# Edges left to remove: -583
# Edges left to remove: -585
# Edges left to remove: -588
# Edges left to remove: -589
# Edges left to remove: -590
# Edges left to remove: -591
# Edges left to remove: -592
# Edges left to remove: -595
# Edges left to remove: -596
# Edges left to remove: -597
# Edges left to remove: -599
# Edges left to remove: -605
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb Cell 12' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb#ch0000013?line=21'>22</a> edges = network.edges(currentNode)
#      <a href='vscode-notebook-cell:/Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb#ch0000013?line=22'>23</a> if (len(edges) == 0):
# ---> <a href='vscode-notebook-cell:/Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb#ch0000013?line=23'>24</a>     currentNode = random.sample(network.nodes(), 1)[0]
#      <a href='vscode-notebook-cell:/Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb#ch0000013?line=24'>25</a>     continue
#      <a href='vscode-notebook-cell:/Users/emanuelwreeby/Plugg/Terminer/VT22/ModelingComplexSystems/Lab2/5a/5a.ipynb#ch0000013?line=25'>26</a> edgesToRemove = random.sample(list(edges), 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py:752, in Graph.nodes(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=660'>661</a> @property
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=661'>662</a> def nodes(self):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=662'>663</a>     """A NodeView of the Graph as G.nodes or G.nodes().
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=663'>664</a>
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=664'>665</a>     Can be used as `G.nodes` for data lookup and for set-like operations.
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=749'>750</a>
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=750'>751</a>     """
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=751'>752</a>     nodes = NodeView(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=752'>753</a>     # Lazy View creation: overload the (class) property on the instance
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=753'>754</a>     # Then future G.nodes use the existing View
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=754'>755</a>     # setattr doesn't work because attribute already exists
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/graph.py?line=755'>756</a>     self.__dict__["nodes"] = nodes
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py:177, in NodeView.__init__(self, graph)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py?line=173'>174</a> def __setstate__(self, state):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py?line=174'>175</a>     self._nodes = state["_nodes"]
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py?line=176'>177</a> def __init__(self, graph):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py?line=177'>178</a>     self._nodes = graph._node
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/classes/reportviews.py?line=179'>180</a> # Mapping methods
#
# KeyboardInterrupt:
